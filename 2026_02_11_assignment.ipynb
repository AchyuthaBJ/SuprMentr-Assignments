# %% [markdown]
# # shopping cart:
# # create shopping cart using list:
# # add items,remove one item, print total items

# %%
cart = ["milk","eggs","bread","biscuit"]
cart.append("butter")
cart.append("peanut butter")
cart.remove("biscuit")
print(cart)
print("Total items in the cart are", len(cart))
# Out:
# ['milk', 'eggs', 'bread', 'butter', 'peanut butter']
# Total items in the cart are 5
