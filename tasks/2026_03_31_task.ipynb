# %% [markdown]
# Task 1: Mini LLM App
#
#  Build:
#
# “AI Study Assistant”
# Features:
# User enters topic
# API returns explanation

# %%
# !pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-2.30.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai) (4.13.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.13.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai)
#   Using cached pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\yuvab\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.30.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------------------------ --- 1.0/1.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 3.1 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.13.0-cp313-cp313-win_amd64.whl (202 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, jiter, distro, annotated-types, pydantic, openai
#
#    --------------- ------------------------ 3/8 [jiter]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ---------------------------------------- 8/8 [openai]
#
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.13.0 openai-2.30.0 pydantic-2.12.5 pydantic-core-2.41.5 sniffio-1.3.1 typing-inspection-0.4.2
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\yuvab\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4",
    input="Write a short bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from openai import OpenAI
# ----> 2 client = OpenAI()
#       4 response = client.responses.create(
#       5     model="gpt-5.4",
#       6     input="Write a short bedtime story about a unicorn."
#       7 )
#       9 print(response.output_text)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\openai\_client.py:139, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     137     api_key = os.environ.get("OPENAI_API_KEY")
#     138 if api_key is None:
# --> 139     raise OpenAIError(
#     140         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     141     )
#     142 if callable(api_key):
#     143     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
